# %% [markdown]
# <a href="https://colab.research.google.com/github/RafsanJany-44/Research_5_Sleep_Stages_Classification/blob/main/Feature_Extraction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
  print('Not using a high-RAM runtime')
else:
  print('You are using a high-RAM runtime!')
# Out:
# Your runtime has 27.3 gigabytes of available RAM
#
# You are using a high-RAM runtime!

# %%
import pandas as pd
import numpy as np

primary_dataset = pd.read_csv("/content/drive/MyDrive/Machine Learning Models/5 Stage Sleep Classification/DataSet/HMC_SleepStage_BioM.csv")
primary_dataset.head()
# Out:
#   Subject Sleep_Stage  Epoch  MeanP_Alpha_F4  MedianF_Alpha_F4  \
# 0   SN002          N1      6             0.0          10.11512
# 1   SN002          N1      7             0.0          10.73951
# 2   SN002          N1      8             0.0           9.36585
# 3   SN002          N1    116             0.0           9.74049
# 4   SN002          N1    117             0.0          10.11512
#
#    MeanF_Alpha_F4  SpectralEdge_Alpha_F4  PeakF_Alpha_F4  MeanP_Beta_F4  \
# 0        17.85756               17.48293        10.24000            0.0
# 1        17.60780               17.10829         9.11610            0.0
# 2        17.60780               16.98341         9.24098            0.0
# 3        15.98439               15.48488         8.36683            0.0
# 4        16.48390               15.98439        12.23805            0.0
#
#    MedianF_Beta_F4  ...  RelativePower_Delta_O2  RelativePower_Gamma_O2  \
# 0         17.73268  ...                0.555528                  0.0377
# 1         16.85854  ...                0.439643                  0.0453
# 2         17.35805  ...                0.437674                  0.0394
# 3         14.61073  ...                0.460881                  0.0220
# 4         15.11024  ...                0.555519                  0.0212
#
#         DAR       DTR     DTABR  RelativePower_Alpha  RelativePower_Beta  \
# 0  3.060271  2.573128  1.751269               0.1210            0.172551
# 1  2.260982  1.905070  1.412719               0.1384            0.199317
# 2  2.350210  1.491650  1.801123               0.1333            0.157235
# 3  2.313885  2.124316  1.661496               0.1535            0.160948
# 4  4.559910  4.038845  2.715109               0.1015            0.111131
#
#    RelativePower_Theta  RelativePower_Delta  RelativePower_Gamma
# 0               0.1439             0.370155             0.035611
# 1               0.1642             0.312834             0.039305
# 2               0.2100             0.313262             0.033253
# 3               0.1672             0.355280             0.017952
# 4               0.1146             0.462663             0.013991
#
# [5 rows x 104 columns]

# %%
dataset = primary_dataset.loc[:,primary_dataset.columns != "Subject"]
dataset = dataset.loc[:,dataset.columns != "Epoch"]
dataset.head()
# Out:
#   Sleep_Stage  MeanP_Alpha_F4  MedianF_Alpha_F4  MeanF_Alpha_F4  \
# 0          N1             0.0          10.11512        17.85756
# 1          N1             0.0          10.73951        17.60780
# 2          N1             0.0           9.36585        17.60780
# 3          N1             0.0           9.74049        15.98439
# 4          N1             0.0          10.11512        16.48390
#
#    SpectralEdge_Alpha_F4  PeakF_Alpha_F4  MeanP_Beta_F4  MedianF_Beta_F4  \
# 0               17.48293        10.24000            0.0         17.73268
# 1               17.10829         9.11610            0.0         16.85854
# 2               16.98341         9.24098            0.0         17.35805
# 3               15.48488         8.36683            0.0         14.61073
# 4               15.98439        12.23805            0.0         15.11024
#
#    MeanF_Beta_F4  SpectralEdge_Beta_F4  ...  RelativePower_Delta_O2  \
# 0       25.35024              27.47317  ...                0.555528
# 1       25.22537              26.97366  ...                0.439643
# 2       26.09951              28.47220  ...                0.437674
# 3       21.72878              22.47805  ...                0.460881
# 4       22.10341              23.47707  ...                0.555519
#
#    RelativePower_Gamma_O2       DAR       DTR     DTABR  RelativePower_Alpha  \
# 0                  0.0377  3.060271  2.573128  1.751269               0.1210
# 1                  0.0453  2.260982  1.905070  1.412719               0.1384
# 2                  0.0394  2.350210  1.491650  1.801123               0.1333
# 3                  0.0220  2.313885  2.124316  1.661496               0.1535
# 4                  0.0212  4.559910  4.038845  2.715109               0.1015
#
#    RelativePower_Beta  RelativePower_Theta  RelativePower_Delta  \
# 0            0.172551               0.1439             0.370155
# 1            0.199317               0.1642             0.312834
# 2            0.157235               0.2100             0.313262
# 3            0.160948               0.1672             0.355280
# 4            0.111131               0.1146             0.462663
#
#    RelativePower_Gamma
# 0             0.035611
# 1             0.039305
# 2             0.033253
# 3             0.017952
# 4             0.013991
#
# [5 rows x 102 columns]

# %%
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()
dataset["Sleep_Stage"]=encoder.fit_transform(dataset["Sleep_Stage"])

# %%
dataset.head()
# Out:
#    Sleep_Stage  MeanP_Alpha_F4  MedianF_Alpha_F4  MeanF_Alpha_F4  \
# 0            0             0.0          10.11512        17.85756
# 1            0             0.0          10.73951        17.60780
# 2            0             0.0           9.36585        17.60780
# 3            0             0.0           9.74049        15.98439
# 4            0             0.0          10.11512        16.48390
#
#    SpectralEdge_Alpha_F4  PeakF_Alpha_F4  MeanP_Beta_F4  MedianF_Beta_F4  \
# 0               17.48293        10.24000            0.0         17.73268
# 1               17.10829         9.11610            0.0         16.85854
# 2               16.98341         9.24098            0.0         17.35805
# 3               15.48488         8.36683            0.0         14.61073
# 4               15.98439        12.23805            0.0         15.11024
#
#    MeanF_Beta_F4  SpectralEdge_Beta_F4  ...  RelativePower_Delta_O2  \
# 0       25.35024              27.47317  ...                0.555528
# 1       25.22537              26.97366  ...                0.439643
# 2       26.09951              28.47220  ...                0.437674
# 3       21.72878              22.47805  ...                0.460881
# 4       22.10341              23.47707  ...                0.555519
#
#    RelativePower_Gamma_O2       DAR       DTR     DTABR  RelativePower_Alpha  \
# 0                  0.0377  3.060271  2.573128  1.751269               0.1210
# 1                  0.0453  2.260982  1.905070  1.412719               0.1384
# 2                  0.0394  2.350210  1.491650  1.801123               0.1333
# 3                  0.0220  2.313885  2.124316  1.661496               0.1535
# 4                  0.0212  4.559910  4.038845  2.715109               0.1015
#
#    RelativePower_Beta  RelativePower_Theta  RelativePower_Delta  \
# 0            0.172551               0.1439             0.370155
# 1            0.199317               0.1642             0.312834
# 2            0.157235               0.2100             0.313262
# 3            0.160948               0.1672             0.355280
# 4            0.111131               0.1146             0.462663
#
#    RelativePower_Gamma
# 0             0.035611
# 1             0.039305
# 2             0.033253
# 3             0.017952
# 4             0.013991
#
# [5 rows x 102 columns]

# %%
dataset.describe()
# Out:
#          Sleep_Stage  MeanP_Alpha_F4  MedianF_Alpha_F4  MeanF_Alpha_F4  \
# count  108451.000000   108451.000000     108451.000000   108451.000000
# mean        1.925506        0.000432          9.083249       15.611500
# std         1.289612        0.012308          1.954552        4.051531
# min         0.000000        0.000000          0.124880        0.874150
# 25%         1.000000        0.000000          8.366830       13.861460
# 50%         2.000000        0.000000          9.116100       15.235120
# 75%         3.000000        0.000000          9.865370       16.733660
# max         4.000000        1.000000        127.875120      127.875120
#
#        SpectralEdge_Alpha_F4  PeakF_Alpha_F4  MeanP_Beta_F4  MedianF_Beta_F4  \
# count          108451.000000   108451.000000  108451.000000    108451.000000
# mean               14.831974        9.080123       0.000279        17.282671
# std                 4.324595        5.159732       0.008035        14.226341
# min                 0.124880        0.124880       0.000000         6.243900
# 25%                12.987320        7.242930       0.000000        12.612680
# 50%                14.236100        8.366830       0.000000        14.485850
# 75%                15.859510        9.990240       0.000000        17.108290
# max               127.875120      127.875120       0.600000       127.875120
#
#        MeanF_Beta_F4  SpectralEdge_Beta_F4  ...  RelativePower_Delta_O2  \
# count  108451.000000         108451.000000  ...           108451.000000
# mean       27.382434             29.446835  ...                0.616795
# std        13.689974             14.190779  ...                0.203306
# min        14.735610             13.361950  ...                0.002844
# 25%        22.103410             22.727800  ...                0.493367
# 50%        23.976590             25.350240  ...                0.623010
# 75%        27.722930             31.344390  ...                0.768692
# max       127.875120            127.875120  ...                1.000000
#
#        RelativePower_Gamma_O2            DAR            DTR          DTABR  \
# count           108451.000000  106998.000000  106998.000000  106998.000000
# mean                 0.044355     164.003983      50.614632      93.843527
# std                  0.099781    2437.036196     603.102976    1436.047359
# min                  0.000000       0.158608       0.259237       0.041824
# 25%                  0.006000       2.976406       2.124648       2.128119
# 50%                  0.013100       5.223130       3.290795       3.563802
# 75%                  0.032000      11.065224       6.247572       7.111501
# max                  0.766200  254164.941700   54147.881810  134858.244800
#
#        RelativePower_Alpha  RelativePower_Beta  RelativePower_Theta  \
# count        108451.000000       108451.000000        108451.000000
# mean              0.093405            0.092234             0.136250
# std               0.057018            0.067891             0.059662
# min               0.000000            0.000000             0.000000
# 25%               0.052200            0.041694             0.091400
# 50%               0.086300            0.078019             0.138000
# 75%               0.124000            0.125928             0.177600
# max               0.374800            0.502920             0.396200
#
#        RelativePower_Delta  RelativePower_Gamma
# count        106998.000000        108451.000000
# mean              1.284550             0.038165
# std               7.703199             0.078006
# min               0.007847             0.000000
# 25%               0.367517             0.005504
# 50%               0.464379             0.012989
# 75%               0.609700             0.032856
# max             467.754726             0.765630
#
# [8 rows x 102 columns]

# %%
columns_name = list(dataset.columns)
columns_name.remove("Sleep_Stage")

# %%
problem_columns = []
problem_rows_numbers = []
for i in columns_name:
  for j in range(108451):
    if dataset[i][j] == 0 or dataset[i][j] == "":
      problem_columns.append(i)
      problem_rows_numbers.append(j)
      print(i,j)
      break

# %%
df = pd.DataFrame({
    'Columns Name': problem_columns,
    'Row Number'  : problem_rows_numbers
    })

df.to_csv("Problems_with.csv")

# %%
for i in problem_columns:
  columns_name.remove(i)

# %%
dataset[columns_name]
# Out:
#         MeanP_Alpha_F4  MedianF_Alpha_F4  MeanF_Alpha_F4  \
# 0                  0.0          10.11512        17.85756
# 1                  0.0          10.73951        17.60780
# 2                  0.0           9.36585        17.60780
# 3                  0.0           9.74049        15.98439
# 4                  0.0          10.11512        16.48390
# ...                ...               ...             ...
# 108446             0.0           9.99024        17.10829
# 108447             0.0          10.48976        16.60878
# 108448             0.0          10.48976        18.73171
# 108449             0.0          10.11512        17.85756
# 108450             0.0          10.61463        21.47902
#
#         SpectralEdge_Alpha_F4  PeakF_Alpha_F4  MeanP_Beta_F4  MedianF_Beta_F4  \
# 0                    17.48293        10.24000            0.0         17.73268
# 1                    17.10829         9.11610            0.0         16.85854
# 2                    16.98341         9.24098            0.0         17.35805
# 3                    15.48488         8.36683            0.0         14.61073
# 4                    15.98439        12.23805            0.0         15.11024
# ...                       ...             ...            ...              ...
# 108446               16.35902         7.49268            0.0         16.85854
# 108447               16.10927         8.86634            0.0         15.73463
# 108448               18.48195         8.86634            0.0         19.73073
# 108449               17.48293        11.61366            0.0         19.73073
# 108450               21.35415         8.24195            0.0         23.22732
#
#         MeanF_Beta_F4  SpectralEdge_Beta_F4  PeakF_Beta_F4  ...  \
# 0            25.35024              27.47317       14.36098  ...
# 1            25.22537              26.97366       16.60878  ...
# 2            26.09951              28.47220       14.98537  ...
# 3            21.72878              22.47805       14.86049  ...
# 4            22.10341              23.47707       12.23805  ...
# ...               ...                   ...            ...  ...
# 108446       26.22439              28.34732       13.86146  ...
# 108447       24.35122              26.09951       13.23707  ...
# 108448       29.09659              32.46829       16.98341  ...
# 108449       29.72098              32.96780       22.85268  ...
# 108450       33.21756              38.08780       21.47902  ...
#
#         RelativePower_Delta_O2  RelativePower_Gamma_O2       DAR       DTR  \
# 0                     0.555528                  0.0377  3.060271  2.573128
# 1                     0.439643                  0.0453  2.260982  1.905070
# 2                     0.437674                  0.0394  2.350210  1.491650
# 3                     0.460881                  0.0220  2.313885  2.124316
# 4                     0.555519                  0.0212  4.559910  4.038845
# ...                        ...                     ...       ...       ...
# 108446                0.322863                  0.0452  1.178776  1.122446
# 108447                0.478966                  0.0240  2.105384  1.750226
# 108448                0.291209                  0.0879  1.123723  1.299364
# 108449                0.707521                  0.0334  5.470780  4.893226
# 108450                0.759440                  0.0496  9.943353  8.551993
#
#            DTABR  RelativePower_Alpha  RelativePower_Beta  \
# 0       1.751269               0.1210            0.172551
# 1       1.412719               0.1384            0.199317
# 2       1.801123               0.1333            0.157235
# 3       1.661496               0.1535            0.160948
# 4       2.715109               0.1015            0.111131
# ...          ...                  ...                 ...
# 108446  0.993903               0.1838            0.228411
# 108447  1.552894               0.1525            0.172402
# 108448  0.733184               0.1738            0.297587
# 108449  2.719666               0.0873            0.124219
# 108450  2.967408               0.0528            0.144826
#
#         RelativePower_Theta  RelativePower_Delta  RelativePower_Gamma
# 0                    0.1439             0.370155             0.035611
# 1                    0.1642             0.312834             0.039305
# 2                    0.2100             0.313262             0.033253
# 3                    0.1672             0.355280             0.017952
# 4                    0.1146             0.462663             0.013991
# ...                     ...                  ...                  ...
# 108446               0.1930             0.216673             0.047498
# 108447               0.1835             0.321097             0.024267
# 108448               0.1503             0.195307             0.093975
# 108449               0.0976             0.477680             0.035929
# 108450               0.0614             0.525054             0.081130
#
# [108451 rows x 101 columns]

# %%
dataset.shape
# Out:
# (108451, 102)

# %%
dataset["Sleep_Stage"].value_counts()
# Out:
# 1    39428
# 2    21290
# 4    19355
# 3    16465
# 0    11913
# Name: Sleep_Stage, dtype: int64

# %%
dataset.head()
# Out:
#    Sleep_Stage  MeanP_Alpha_F4  MedianF_Alpha_F4  MeanF_Alpha_F4  \
# 0            0             0.0          10.11512        17.85756
# 1            0             0.0          10.73951        17.60780
# 2            0             0.0           9.36585        17.60780
# 3            0             0.0           9.74049        15.98439
# 4            0             0.0          10.11512        16.48390
#
#    SpectralEdge_Alpha_F4  PeakF_Alpha_F4  MeanP_Beta_F4  MedianF_Beta_F4  \
# 0               17.48293        10.24000            0.0         17.73268
# 1               17.10829         9.11610            0.0         16.85854
# 2               16.98341         9.24098            0.0         17.35805
# 3               15.48488         8.36683            0.0         14.61073
# 4               15.98439        12.23805            0.0         15.11024
#
#    MeanF_Beta_F4  SpectralEdge_Beta_F4  ...  RelativePower_Delta_O2  \
# 0       25.35024              27.47317  ...                0.555528
# 1       25.22537              26.97366  ...                0.439643
# 2       26.09951              28.47220  ...                0.437674
# 3       21.72878              22.47805  ...                0.460881
# 4       22.10341              23.47707  ...                0.555519
#
#    RelativePower_Gamma_O2       DAR       DTR     DTABR  RelativePower_Alpha  \
# 0                  0.0377  3.060271  2.573128  1.751269               0.1210
# 1                  0.0453  2.260982  1.905070  1.412719               0.1384
# 2                  0.0394  2.350210  1.491650  1.801123               0.1333
# 3                  0.0220  2.313885  2.124316  1.661496               0.1535
# 4                  0.0212  4.559910  4.038845  2.715109               0.1015
#
#    RelativePower_Beta  RelativePower_Theta  RelativePower_Delta  \
# 0            0.172551               0.1439             0.370155
# 1            0.199317               0.1642             0.312834
# 2            0.157235               0.2100             0.313262
# 3            0.160948               0.1672             0.355280
# 4            0.111131               0.1146             0.462663
#
#    RelativePower_Gamma
# 0             0.035611
# 1             0.039305
# 2             0.033253
# 3             0.017952
# 4             0.013991
#
# [5 rows x 102 columns]

# %%
temp=["DAR","DTR","DTABR","RelativePower_Delta"]

for i in temp:
  columns_name.remove(i)

# %%
X = dataset[columns_name]#dataset.loc[:,dataset.columns != "Sleep_Stage"]
y = dataset["Sleep_Stage"]

# %%
np.any(np.isnan(X))
np.all(np.isfinite(X))
# Out:
# False

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 108451 entries, 0 to 108450
# Data columns (total 97 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   MeanP_Alpha_F4          108451 non-null  float64
#  1   MedianF_Alpha_F4        108451 non-null  float64
#  2   MeanF_Alpha_F4          108451 non-null  float64
#  3   SpectralEdge_Alpha_F4   108451 non-null  float64
#  4   PeakF_Alpha_F4          108451 non-null  float64
#  5   MeanP_Beta_F4           108451 non-null  float64
#  6   MedianF_Beta_F4         108451 non-null  float64
#  7   MeanF_Beta_F4           108451 non-null  float64
#  8   SpectralEdge_Beta_F4    108451 non-null  float64
#  9   PeakF_Beta_F4           108451 non-null  float64
#  10  MeanP_Theta_F4          108451 non-null  float64
#  11  MedianF_Theta_F4        108451 non-null  float64
#  12  MeanF_Theta_F4          108451 non-null  float64
#  13  SpectralEdge_Theta_F4   108451 non-null  float64
#  14  PeakF_Theta_F4          108451 non-null  float64
#  15  MeanP_Delta_F4          108451 non-null  float64
#  16  MedianF_Delta_F4        108451 non-null  float64
#  17  MeanF_Delta_F4          108451 non-null  float64
#  18  SpectralEdge_Delta_F4   108451 non-null  float64
#  19  PeakF_Delta_F4          108451 non-null  float64
#  20  MeanP_Gamma_F4          108451 non-null  float64
#  21  MedianF_Gamma_F4        108451 non-null  float64
#  22  MeanF_Gamma_F4          108451 non-null  float64
#  23  SpectralEdge_Gamma_F4   108451 non-null  float64
#  24  PeakF_Gamma_F4          108451 non-null  float64
#  25  MeanP_Alpha_C4          108451 non-null  float64
#  26  MedianF_Alpha_C4        108451 non-null  float64
#  27  MeanF_Alpha_C4          108451 non-null  float64
#  28  SpectralEdge_Alpha_C4   108451 non-null  float64
#  29  PeakF_Alpha_C4          108451 non-null  float64
#  30  MeanP_Beta_C4           108451 non-null  float64
#  31  MedianF_Beta_C4         108451 non-null  float64
#  32  MeanF_Beta_C4           108451 non-null  float64
#  33  SpectralEdge_Beta_C4    108451 non-null  float64
#  34  PeakF_Beta_C4           108451 non-null  float64
#  35  MeanP_Theta_C4          108451 non-null  float64
#  36  MedianF_Theta_C4        108451 non-null  float64
#  37  MeanF_Theta_C4          108451 non-null  float64
#  38  SpectralEdge_Theta_C4   108451 non-null  float64
#  39  PeakF_Theta_C4          108451 non-null  float64
#  40  MeanP_Delta_C4          108451 non-null  float64
#  41  MedianF_Delta_C4        108451 non-null  float64
#  42  MeanF_Delta_C4          108451 non-null  float64
#  43  SpectralEdge_Delta_C4   108451 non-null  float64
#  44  PeakF_Delta_C4          108451 non-null  float64
#  45  MeanP_Gamma_C4          108451 non-null  float64
#  46  MedianF_Gamma_C4        108451 non-null  float64
#  47  MeanF_Gamma_C4          108451 non-null  float64
#  48  SpectralEdge_Gamma_C4   108451 non-null  float64
#  49  PeakF_Gamma_C4          108451 non-null  float64
#  50  MeanP_Alpha_O2          108451 non-null  float64
#  51  MedianF_Alpha_O2        108451 non-null  float64
#  52  MeanF_Alpha_O2          108451 non-null  float64
#  53  SpectralEdge_Alpha_O2   108451 non-null  float64
#  54  PeakF_Alpha_O2          108451 non-null  float64
#  55  MeanP_Beta_O2           108451 non-null  float64
#  56  MedianF_Beta_O2         108451 non-null  float64
#  57  MeanF_Beta_O2           108451 non-null  float64
#  58  SpectralEdge_Beta_O2    108451 non-null  float64
#  59  PeakF_Beta_O2           108451 non-null  float64
#  60  MeanP_Theta_O2          108451 non-null  float64
#  61  MedianF_Theta_O2        108451 non-null  float64
#  62  MeanF_Theta_O2          108451 non-null  float64
#  63  SpectralEdge_Theta_O2   108451 non-null  float64
#  64  PeakF_Theta_O2          108451 non-null  float64
#  65  MeanP_Delta_O2          108451 non-null  float64
#  66  MedianF_Delta_O2        108451 non-null  float64
#  67  MeanF_Delta_O2          108451 non-null  float64
#  68  SpectralEdge_Delta_O2   108451 non-null  float64
#  69  PeakF_Delta_O2          108451 non-null  float64
#  70  MeanP_Gamma_O2          108451 non-null  float64
#  71  MedianF_Gamma_O2        108451 non-null  float64
#  72  MeanF_Gamma_O2          108451 non-null  float64
#  73  SpectralEdge_Gamma_O2   108451 non-null  float64
#  74  PeakF_Gamma_O2          108451 non-null  float64
#  75  TotalPower_F4           108451 non-null  float64
#  76  TotalPower_C4           108451 non-null  float64
#  77  TotalPower_O2           108451 non-null  float64
#  78  RelativePower_Alpha_F4  108451 non-null  float64
#  79  RelativePower_Beta_F4   108451 non-null  float64
#  80  RelativePower_Theta_F4  108451 non-null  float64
#  81  RelativePower_Delta_F4  108451 non-null  float64
#  82  RelativePower_Gamma_F4  108451 non-null  float64
#  83  RelativePower_Alpha_C4  108451 non-null  float64
#  84  RelativePower_Beta_C4   108451 non-null  float64
#  85  RelativePower_Theta_C4  108451 non-null  float64
#  86  RelativePower_Delta_C4  106998 non-null  float64
#  87  RelativePower_Gamma_C4  108451 non-null  float64
#  88  RelativePower_Alpha_O2  108451 non-null  float64
#  89  RelativePower_Beta_O2   108451 non-null  float64
#  90  RelativePower_Theta_O2  108451 non-null  float64
#  91  RelativePower_Delta_O2  108451 non-null  float64
#  92  RelativePower_Gamma_O2  108451 non-null  float64
#  93  RelativePower_Alpha     108451 non-null  float64
#  94  RelativePower_Beta      108451 non-null  float64
#  95  RelativePower_Theta     108451 non-null  float64
#  96  RelativePower_Gamma     108451 non-null  float64
# dtypes: float64(97)
# memory usage: 80.3 MB

# %%
number_of_feat=int(input("Number Of Best Features: "))
# Out:
# Number Of Best Features: 30

# %% [markdown]
# #Filter Method (Model Free)

# %%
from sklearn.feature_selection import SelectKBest
bestfeatures_1 = SelectKBest(k=10)
fit = bestfeatures_1.fit(X,y)
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(X.columns)
featureScores = pd.concat([dfcolumns,dfscores],axis=1)
featureScores.columns = ['Best_columns','Score_bestfeatures_1']
lyst = featureScores.nlargest(number_of_feat,'Score_bestfeatures_1')
lyst.to_csv('Filter_Method_bestfeatures_1.csv')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-81-88ae0c2d3b85> in <module>
#       1 from sklearn.feature_selection import SelectKBest
#       2 bestfeatures_1 = SelectKBest(k=10)
# ----> 3 fit = bestfeatures_1.fit(X,y)
#       4 dfscores = pd.DataFrame(fit.scores_)
#       5 dfcolumns = pd.DataFrame(X.columns)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_selection/_univariate_selection.py in fit(self, X, y)
#     396         """
#     397         X, y = self._validate_data(
# --> 398             X, y, accept_sparse=["csr", "csc"], multi_output=True
#     399         )
#     400
#
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     579                 y = check_array(y, **check_y_params)
#     580             else:
# --> 581                 X, y = check_X_y(X, y, **check_params)
#     582             out = X, y
#     583
#
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#     974         ensure_min_samples=ensure_min_samples,
#     975         ensure_min_features=ensure_min_features,
# --> 976         estimator=estimator,
#     977     )
#     978
#
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     798
#     799         if force_all_finite:
# --> 800             _assert_all_finite(array, allow_nan=force_all_finite == "allow-nan")
#     801
#     802     if ensure_min_samples > 0:
#
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py in _assert_all_finite(X, allow_nan, msg_dtype)
#     114             raise ValueError(
#     115                 msg_err.format(
# --> 116                     type_err, msg_dtype if msg_dtype is not None else X.dtype
#     117                 )
#     118             )
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').

# %%
from sklearn.feature_selection import SelectFpr, f_classif

bestfeatures_3=SelectFpr(f_classif, alpha=0.1)
fit = bestfeatures_3.fit(X,y)
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(X.columns)
featureScores = pd.concat([dfcolumns,dfscores],axis=1)
featureScores.columns = ['Specs','Score_bestfeatures_3']
lyst=featureScores.nlargest(number_of_feat,'Score_bestfeatures_3')

lyst.to_csv('Filter_Method_bestfeatures_3.csv')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-f06f3259d46c> in <module>
#       2
#       3 bestfeatures_3=SelectFpr(f_classif, alpha=0.1)
# ----> 4 fit = bestfeatures_3.fit(X,y)
#       5 dfscores = pd.DataFrame(fit.scores_)
#       6 dfcolumns = pd.DataFrame(X.columns)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_selection/_univariate_selection.py in fit(self, X, y)
#     396         """
#     397         X, y = self._validate_data(
# --> 398             X, y, accept_sparse=["csr", "csc"], multi_output=True
#     399         )
#     400
#
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     579                 y = check_array(y, **check_y_params)
#     580             else:
# --> 581                 X, y = check_X_y(X, y, **check_params)
#     582             out = X, y
#     583
#
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#     974         ensure_min_samples=ensure_min_samples,
#     975         ensure_min_features=ensure_min_features,
# --> 976         estimator=estimator,
#     977     )
#     978
#
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     798
#     799         if force_all_finite:
# --> 800             _assert_all_finite(array, allow_nan=force_all_finite == "allow-nan")
#     801
#     802     if ensure_min_samples > 0:
#
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py in _assert_all_finite(X, allow_nan, msg_dtype)
#     114             raise ValueError(
#     115                 msg_err.format(
# --> 116                     type_err, msg_dtype if msg_dtype is not None else X.dtype
#     117                 )
#     118             )
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').

# %% [markdown]
# #Pearson’s with f_regression()

# %%
from sklearn.datasets import make_regression
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_regression
import pandas as pd


fs = SelectKBest(score_func=f_regression, k=5)
fit = fs.fit(X,y)

dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(df.columns)
featureScores = pd.concat([dfcolumns,dfscores],axis=1)

featureScores.columns = ['Best_columns','Score_pearsons'] 


lyst = featureScores.nlargest(30,'Score_pearsons')

lyst.to_csv('Filter_Method_Pearson’s_with_f_regression.csv')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-8e66d8e6df2b> in <module>
#       6
#       7 fs = SelectKBest(score_func=f_regression, k=5)
# ----> 8 fit = fs.fit(X,y)
#       9
#      10 dfscores = pd.DataFrame(fit.scores_)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_selection/_univariate_selection.py in fit(self, X, y)
#     396         """
#     397         X, y = self._validate_data(
# --> 398             X, y, accept_sparse=["csr", "csc"], multi_output=True
#     399         )
#     400
#
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     579                 y = check_array(y, **check_y_params)
#     580             else:
# --> 581                 X, y = check_X_y(X, y, **check_params)
#     582             out = X, y
#     583
#
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#     974         ensure_min_samples=ensure_min_samples,
#     975         ensure_min_features=ensure_min_features,
# --> 976         estimator=estimator,
#     977     )
#     978
#
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     798
#     799         if force_all_finite:
# --> 800             _assert_all_finite(array, allow_nan=force_all_finite == "allow-nan")
#     801
#     802     if ensure_min_samples > 0:
#
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py in _assert_all_finite(X, allow_nan, msg_dtype)
#     114             raise ValueError(
#     115                 msg_err.format(
# --> 116                     type_err, msg_dtype if msg_dtype is not None else X.dtype
#     117                 )
#     118             )
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').

# %% [markdown]
# #ANOVA with f_classif()

# %%
from sklearn.datasets import make_classification
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_classif
import pandas as pd



fs = SelectKBest(score_func=f_classif, k=5)
fit = fs.fit(X,y)
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(df.columns)

featureScores = pd.concat([dfcolumns,dfscores],axis=1)

featureScores.columns = ['Best_columns','Score_ANOVA'] 

lyst = featureScores.nlargest(30,'Score_ANOVA')
lyst.to_csv('Filter_Method_ANOVA_with_f_classif.csv')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-56-8c24de752b7d> in <module>
#       7
#       8 fs = SelectKBest(score_func=f_classif, k=5)
# ----> 9 fit = fs.fit(X,y)
#      10 dfscores = pd.DataFrame(fit.scores_)
#      11 dfcolumns = pd.DataFrame(df.columns)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_selection/_univariate_selection.py in fit(self, X, y)
#     396         """
#     397         X, y = self._validate_data(
# --> 398             X, y, accept_sparse=["csr", "csc"], multi_output=True
#     399         )
#     400
#
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     579                 y = check_array(y, **check_y_params)
#     580             else:
# --> 581                 X, y = check_X_y(X, y, **check_params)
#     582             out = X, y
#     583
#
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#     974         ensure_min_samples=ensure_min_samples,
#     975         ensure_min_features=ensure_min_features,
# --> 976         estimator=estimator,
#     977     )
#     978
#
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     798
#     799         if force_all_finite:
# --> 800             _assert_all_finite(array, allow_nan=force_all_finite == "allow-nan")
#     801
#     802     if ensure_min_samples > 0:
#
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py in _assert_all_finite(X, allow_nan, msg_dtype)
#     114             raise ValueError(
#     115                 msg_err.format(
# --> 116                     type_err, msg_dtype if msg_dtype is not None else X.dtype
#     117                 )
#     118             )
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
